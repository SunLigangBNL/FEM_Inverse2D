# %%
# Inverse scheme reattack.
# By: Ligang Sun.
# Date: 04/17/2025.
# You reap what you sow.
# Goal of this file: complete the workflow with higher dimension searching space.

# %%
import os
import sys
import numpy as np
import matplotlib.pyplot as plt

# %%
jcm_optimizer_path = "/home/sun2024/JCMoptimizer"
sys.path.insert(0, os.path.join(jcm_optimizer_path, "interface", "python"))
from jcmoptimizer import Server, Client, Study, Observation

# %%
from forward_model import ForwardModel
from forward_model.modules import ConfigParameter

# %%
# Statement of the problem.
thetaarray=np.linspace(-20,30,6) # for now we still use the simple Reference 1.

# source definition: unit m.
lambda0=1e-9 #**********************************check!!
# geometry: unit in m.
pitch=80e-9
line=40e-9
height=30e-9
thickness=1e-3 # substrate with thickness being 1mm.
rr=5 # sample detector distance in m.
# material parameter.
epsilonr1=0.99964+0.0000295399j # grating structure************check!!
epsilonr2=0.999435 # substrate********************check!!

dimqxbranch=5 # number of interested Qx peak per branch.
diroutput="/home/sun2024/Resource/JCM/Inverse_2D/simulation2a/Reference1/Output_all"

config=ConfigParameter(pitch, line, height, thickness, rr, epsilonr1, epsilonr2, lambda0, dimqxbranch)

# %%
# Forward model initialization.
fm=ForwardModel(config, Multiplicity=1, NThreads=6)

# %%
# Part 1: generate numerical reference.
Qzdomain, intref, intuncertainty =fm.CompRef(thetaarray,config,diroutput)
# Out:
# current thata :  -20.0
# matmeta generated.
# Numerical reference generated.

# %%
# Part 2: intensity with an arbitray initial guess. The real case.
initguess={'cd':28, 'h': 32}
intrandom=fm.ModelEvaluate(keys=initguess,config=config)
# Out:
# current thata :  -20.0
# current thata :  -10.0
# current thata :  0.0
# current thata :  10.0
# current thata :  20.0
# current thata :  30.0
# {'IP': '0.0.0.0',
#  'Jobs': {'Finished': [],
#           'Pending': [],
#           'ReceivingData': [],
#           'Running': [1672505107],
#           'SendingData': [],
#           'Waiting': [1230167561,
#                       1948604556,
#                       138545679,
#                       1756440730,
#                       1186681655]},
#  'Port': 33995}
# All status {'IP': '0.0.0.0', 'Port': 33995, 'Jobs': {'Finished': [], 'Pending': [], 'ReceivingData': [], 'Running': [1672505107], 'SendingData': [], 'Waiting': [1230167561, 1948604556, 138545679, 1756440730, 1186681655]}}
# All logs saved in /home/sun2024/Resource/JCM/Inverse_2D/simulation2a/forward_model/jcm/logs_all.txt.
# matmeta generated.
# Forward model evaluated.
# 2025-04-17 23:32:24: Polling server at http://localhost:4554
# 2025-04-17 23:32:25: Optimization server is running
# 2025-04-17 23:32:33: The dashboard is accessible via http://localhost:4554/dashboard/pararecon_attack_102?token=5MWqXqy_Ox9zgpslEJ-JkneTaWN-32e2jYOlM4H1U-k
# 2025-04-17 23:32:44: Computing suggestion 1.
# 2025-04-17 23:32:44: Calculated suggestion 1 [30.6148, 29.5925] in 0.00342 s.
# current thata :  -20.0
# current thata :  -10.0
# current thata :  0.0
# current thata :  10.0
# current thata :  20.0
# current thata :  30.0
# {'IP': '0.0.0.0',
#  'Jobs': {'Finished': [],
#           'Pending': [],
#           'ReceivingData': [],
#           'Running': [1111278152],
#           'SendingData': [],
#           'Waiting': [484556920,
#                       1322691419,
#                       2030726211,
#                       572142694,
#                       1626288376]},
#  'Port': 33995}
# All status {'IP': '0.0.0.0', 'Port': 33995, 'Jobs': {'Finished': [], 'Pending': [], 'ReceivingData': [], 'Running': [1111278152], 'SendingData': [], 'Waiting': [484556920, 1322691419, 2030726211, 572142694, 1626288376]}}
# All logs saved in /home/sun2024/Resource/JCM/Inverse_2D/simulation2a/forward_model/jcm/logs_all.txt.
# matmeta generated.
# Forward model evaluated.
# 2025-04-17 23:35:26: Observation [0.0784429, 0.0713201, 0.0691155, 0.0714929, 0.0789243, ...] for suggestion 1 acquired in 161 s
# 2025-04-17 23:35:26: Computing suggestion 2.
# 2025-04-17 23:35:26: Calculated suggestion 2 [31.8227, 28.1448] in 0.00171 s.
# current thata :  -20.0
# current thata :  -10.0
# current thata :  0.0
# current thata :  10.0
# current thata :  20.0
# current thata :  30.0
# {'IP': '0.0.0.0',
#  'Jobs': {'Finished': [],
#           'Pending': [],
#           'ReceivingData': [],
#           'Running': [2115929738],
#           'SendingData': [],
#           'Waiting': [49618559, 738499808, 1799254898, 59871088, 1029001504]},
#  'Port': 33995}
# All status {'IP': '0.0.0.0', 'Port': 33995, 'Jobs': {'Finished': [], 'Pending': [], 'ReceivingData': [], 'Running': [2115929738], 'SendingData': [], 'Waiting': [49618559, 738499808, 1799254898, 59871088, 1029001504]}}
# All logs saved in /home/sun2024/Resource/JCM/Inverse_2D/simulation2a/forward_model/jcm/logs_all.txt.
# matmeta generated.
# Forward model evaluated.
# 2025-04-17 23:38:13: Observation [0.0741517, 0.0671723, 0.0650374, 0.0673749, 0.0746941, ...] for suggestion 2 acquired in 167 s
# 2025-04-17 23:38:13: Computing suggestion 3.
# 2025-04-17 23:38:13: Calculated suggestion 3 [29.3169, 30.795] in 0.00139 s.
# current thata :  -20.0
# current thata :  -10.0
# current thata :  0.0
# current thata :  10.0
# current thata :  20.0
# current thata :  30.0
# {'IP': '0.0.0.0',
#  'Jobs': {'Finished': [],
#           'Pending': [],
#           'ReceivingData': [],
#           'Running': [816059795],
#           'SendingData': [],
#           'Waiting': [2082784009,
#                       1450365345,
#                       1604850978,
#                       589686721,
#                       340234118]},
#  'Port': 33995}
# All status {'IP': '0.0.0.0', 'Port': 33995, 'Jobs': {'Finished': [], 'Pending': [], 'ReceivingData': [], 'Running': [816059795], 'SendingData': [], 'Waiting': [2082784009, 1450365345, 1604850978, 589686721, 340234118]}}
# All logs saved in /home/sun2024/Resource/JCM/Inverse_2D/simulation2a/forward_model/jcm/logs_all.txt.
# matmeta generated.
# Forward model evaluated.
# 2025-04-17 23:40:55: Observation [0.0807147, 0.0736109, 0.07139, 0.0737528, 0.081131, ...] for suggestion 3 acquired in 161 s
# 2025-04-17 23:40:55: Computing suggestion 4.
# 2025-04-17 23:40:55: Calculated suggestion 4 [30.1224, 30.0645] in 0.165 s.
# current thata :  -20.0
# current thata :  -10.0
# current thata :  0.0
# current thata :  10.0
# current thata :  20.0
# current thata :  30.0
# {'IP': '0.0.0.0',
#  'Jobs': {'Finished': [],
#           'Pending': [],
#           'ReceivingData': [],
#           'Running': [1856876880],
#           'SendingData': [],
#           'Waiting': [2001236818,
#                       291331973,
#                       675078379,
#                       1003347299,
#                       1155299885]},
#  'Port': 33995}
# All status {'IP': '0.0.0.0', 'Port': 33995, 'Jobs': {'Finished': [], 'Pending': [], 'ReceivingData': [], 'Running': [1856876880], 'SendingData': [], 'Waiting': [2001236818, 291331973, 675078379, 1003347299, 1155299885]}}
# All logs saved in /home/sun2024/Resource/JCM/Inverse_2D/simulation2a/forward_model/jcm/logs_all.txt.
# matmeta generated.
# Forward model evaluated.
# 2025-04-17 23:43:34: Observation [0.0794608, 0.0723323, 0.0701174, 0.0724934, 0.0799178, ...] for suggestion 4 acquired in 159 s
# 2025-04-17 23:43:34: Computing suggestion 5.
# 2025-04-17 23:43:34: Calculated suggestion 5 [30.0092, 30.1685] in 0.212 s.
# current thata :  -20.0
# current thata :  -10.0
# current thata :  0.0
# current thata :  10.0
# current thata :  20.0
# current thata :  30.0
# {'IP': '0.0.0.0',
#  'Jobs': {'Finished': [],
#           'Pending': [],
#           'ReceivingData': [],
#           'Running': [285375719],
#           'SendingData': [],
#           'Waiting': [1680363108,
#                       1961981005,
#                       357391140,
#                       1350293968,
#                       1893640992]},
#  'Port': 33995}
# All status {'IP': '0.0.0.0', 'Port': 33995, 'Jobs': {'Finished': [], 'Pending': [], 'ReceivingData': [], 'Running': [285375719], 'SendingData': [], 'Waiting': [1680363108, 1961981005, 357391140, 1350293968, 1893640992]}}
# All logs saved in /home/sun2024/Resource/JCM/Inverse_2D/simulation2a/forward_model/jcm/logs_all.txt.
# matmeta generated.
# Forward model evaluated.
# 2025-04-17 23:46:05: Observation [0.0796596, 0.0725328, 0.0703163, 0.0726912, 0.0801113, ...] for suggestion 5 acquired in 151 s
# 2025-04-17 23:46:05: Computing suggestion 6.
# 2025-04-17 23:46:06: Calculated suggestion 6 [29.9797, 30.1553] in 0.24 s.
# current thata :  -20.0
# current thata :  -10.0
# current thata :  0.0
# current thata :  10.0
# current thata :  20.0
# current thata :  30.0
# {'IP': '0.0.0.0',
#  'Jobs': {'Finished': [],
#           'Pending': [],
#           'ReceivingData': [],
#           'Running': [1847102309],
#           'SendingData': [],
#           'Waiting': [1861543741,
#                       1774269861,
#                       1481964807,
#                       943807614,
#                       1804680307]},
#  'Port': 33995}
# All status {'IP': '0.0.0.0', 'Port': 33995, 'Jobs': {'Finished': [], 'Pending': [], 'ReceivingData': [], 'Running': [1847102309], 'SendingData': [], 'Waiting': [1861543741, 1774269861, 1481964807, 943807614, 1804680307]}}
# All logs saved in /home/sun2024/Resource/JCM/Inverse_2D/simulation2a/forward_model/jcm/logs_all.txt.
# matmeta generated.
# Forward model evaluated.
# 2025-04-17 23:48:37: Observation [0.0795186, 0.0724013, 0.0701882, 0.0725601, 0.0799703, ...] for suggestion 6 acquired in 151 s
# 2025-04-17 23:48:37: Computing suggestion 7.
# 2025-04-17 23:48:37: Calculated suggestion 7 [29.9985, 30.0064] in 0.255 s.
# current thata :  -20.0
# current thata :  -10.0
# current thata :  0.0
# current thata :  10.0
# current thata :  20.0
# current thata :  30.0
# {'IP': '0.0.0.0',
#  'Jobs': {'Finished': [],
#           'Pending': [],
#           'ReceivingData': [],
#           'Running': [298890422],
#           'SendingData': [],
#           'Waiting': [376675580, 886851197, 243540231, 1729784484, 280141195]},
#  'Port': 33995}
# All status {'IP': '0.0.0.0', 'Port': 33995, 'Jobs': {'Finished': [], 'Pending': [], 'ReceivingData': [], 'Running': [298890422], 'SendingData': [], 'Waiting': [376675580, 886851197, 243540231, 1729784484, 280141195]}}
# All logs saved in /home/sun2024/Resource/JCM/Inverse_2D/simulation2a/forward_model/jcm/logs_all.txt.
# matmeta generated.
# Forward model evaluated.
# 2025-04-17 23:51:06: Observation [0.078861, 0.0717741, 0.0695734, 0.0719359, 0.0793195, ...] for suggestion 7 acquired in 149 s
# 2025-04-17 23:51:06: Computing suggestion 8.
# 2025-04-17 23:51:06: Calculated suggestion 8 [30, 29.9999] in 0.291 s.
# current thata :  -20.0
# current thata :  -10.0
# current thata :  0.0
# current thata :  10.0
# current thata :  20.0
# current thata :  30.0
# {'IP': '0.0.0.0',
#  'Jobs': {'Finished': [],
#           'Pending': [],
#           'ReceivingData': [],
#           'Running': [395937217],
#           'SendingData': [],
#           'Waiting': [1818164712, 1463457802, 128413731, 251693412, 574215126]},
#  'Port': 33995}
# All status {'IP': '0.0.0.0', 'Port': 33995, 'Jobs': {'Finished': [], 'Pending': [], 'ReceivingData': [], 'Running': [395937217], 'SendingData': [], 'Waiting': [1818164712, 1463457802, 128413731, 251693412, 574215126]}}
# All logs saved in /home/sun2024/Resource/JCM/Inverse_2D/simulation2a/forward_model/jcm/logs_all.txt.
# matmeta generated.
# Forward model evaluated.
# 2025-04-17 23:53:42: Observation [0.0788344, 0.0717486, 0.0695484, 0.0719108, 0.079293, ...] for suggestion 8 acquired in 155 s
# 2025-04-17 23:53:42: Computing suggestion 9.
# 2025-04-17 23:53:42: Calculated suggestion 9 [29.9999, 30] in 0.223 s.
# current thata :  -20.0
# current thata :  -10.0
# current thata :  0.0
# current thata :  10.0
# current thata :  20.0
# current thata :  30.0
# {'IP': '0.0.0.0',
#  'Jobs': {'Finished': [],
#           'Pending': [],
#           'ReceivingData': [],
#           'Running': [590031002],
#           'SendingData': [],
#           'Waiting': [316106101,
#                       1908050616,
#                       1936872942,
#                       993161440,
#                       1497384097]},
#  'Port': 33995}
# All status {'IP': '0.0.0.0', 'Port': 33995, 'Jobs': {'Finished': [], 'Pending': [], 'ReceivingData': [], 'Running': [590031002], 'SendingData': [], 'Waiting': [316106101, 1908050616, 1936872942, 993161440, 1497384097]}}
# All logs saved in /home/sun2024/Resource/JCM/Inverse_2D/simulation2a/forward_model/jcm/logs_all.txt.
# matmeta generated.
# Forward model evaluated.
# 2025-04-17 23:56:27: Observation [0.0788347, 0.0717487, 0.0695485, 0.0719109, 0.0792932, ...] for suggestion 9 acquired in 165 s
# 2025-04-17 23:56:27: Computing suggestion 10.
# 2025-04-17 23:56:28: Calculated suggestion 10 [29.9999, 30] in 0.264 s.
# current thata :  -20.0
# 2025-04-17 23:56:28: Study finished. Maximum number of observations max_iter=10 obtained.
# current thata :  -10.0
# current thata :  0.0
# current thata :  10.0
# current thata :  20.0
# current thata :  30.0
# {'IP': '0.0.0.0',
#  'Jobs': {'Finished': [],
#           'Pending': [],
#           'ReceivingData': [],
#           'Running': [1336996908],
#           'SendingData': [],
#           'Waiting': [1178301912, 303964300, 2069862026, 48823500, 1331151411]},
#  'Port': 33995}
# All status {'IP': '0.0.0.0', 'Port': 33995, 'Jobs': {'Finished': [], 'Pending': [], 'ReceivingData': [], 'Running': [1336996908], 'SendingData': [], 'Waiting': [1178301912, 303964300, 2069862026, 48823500, 1331151411]}}
# All logs saved in /home/sun2024/Resource/JCM/Inverse_2D/simulation2a/forward_model/jcm/logs_all.txt.
# matmeta generated.
# Forward model evaluated.
# 2025-04-17 23:59:09: Observation [0.0788346, 0.0717488, 0.0695484, 0.071911, 0.0792933, ...] for suggestion 10 acquired in 161 s
# Relative error report:
# relative error of the 1th peak, 0.04
# relative error of the 2th peak, 0.38
# relative error of the 3th peak, 0.22
# relative error of the 4th peak, 0.09
# relative error of the 5th peak, 0.11
# Overall relative error: 0.17
# Reconstructed parameters with chi-squared value 1.1507e-07:
#   cd = 30.000 +/- 0.000
#   h = 30.000 +/- 0.000
# {'cd': 29.999926293654944, 'h': 29.999981020417458}
# current thata :  -20.0
# current thata :  -10.0
# current thata :  0.0
# current thata :  10.0
# current thata :  20.0
# current thata :  30.0
# {'IP': '0.0.0.0',
#  'Jobs': {'Finished': [],
#           'Pending': [],
#           'ReceivingData': [],
#           'Running': [406416119],
#           'SendingData': [],
#           'Waiting': [1360698558,
#                       1722543357,
#                       2143989560,
#                       704704510,
#                       464247391]},
#  'Port': 33995}
# All status {'IP': '0.0.0.0', 'Port': 33995, 'Jobs': {'Finished': [], 'Pending': [], 'ReceivingData': [], 'Running': [406416119], 'SendingData': [], 'Waiting': [1360698558, 1722543357, 2143989560, 704704510, 464247391]}}
# All logs saved in /home/sun2024/Resource/JCM/Inverse_2D/simulation2a/forward_model/jcm/logs_all.txt.
# matmeta generated.
# Forward model evaluated.
# Relative error report:
# Relative error report:
# relative error of the 1th peak, 0.00
# relative error of the 2th peak, 0.00
# relative error of the 3th peak, 0.00
# relative error of the 4th peak, 0.00
# relative error of the 5th peak, 0.00
# Overall relative error: 0.00
# current thata :  -20.0
# current thata :  -10.0
# current thata :  0.0
# current thata :  10.0
# current thata :  20.0
# current thata :  30.0
# {'IP': '0.0.0.0',
#  'Jobs': {'Finished': [],
#           'Pending': [],
#           'ReceivingData': [],
#           'Running': [411061995],
#           'SendingData': [],
#           'Waiting': [71761075, 129472282, 1989608533, 130389629, 1243998172]},
#  'Port': 33995}
# All status {'IP': '0.0.0.0', 'Port': 33995, 'Jobs': {'Finished': [], 'Pending': [], 'ReceivingData': [], 'Running': [411061995], 'SendingData': [], 'Waiting': [71761075, 129472282, 1989608533, 130389629, 1243998172]}}
# All logs saved in /home/sun2024/Resource/JCM/Inverse_2D/simulation2a/forward_model/jcm/logs_all.txt.
# matmeta generated.
# Forward model evaluated.
# [[7.88349693e-02 8.76337384e-03 2.00188919e-03 1.54805430e-03
#   1.02126292e-03]
#  [7.17491209e-02 8.54783140e-03 1.01885916e-03 1.66845954e-03
#   3.16625989e-04]
#  [6.95487668e-02 8.45852987e-03 7.32927968e-04 1.68847236e-03
#   6.89197905e-05]
#  [7.19110725e-02 8.56020764e-03 1.22920253e-03 1.65472832e-03
#   5.98381699e-04]
#  [7.92934594e-02 8.79657326e-03 2.39096378e-03 1.49289885e-03
#   1.23820964e-03]
#  [9.29728256e-02 8.90424234e-03 3.56360767e-03 1.00376412e-03
#   7.94845257e-04]]
# Relative error report:
# relative error of the 1th peak, 0.00
# relative error of the 2th peak, 0.00
# relative error of the 3th peak, 0.00
# relative error of the 4th peak, 0.00
# relative error of the 5th peak, 0.00
# Overall relative error: 0.00

# %%
# Initial guess vs. reference.
colorarray=['blue','orange','black','green','red']
plt.figure(figsize=(12, 4))

plt.subplot(1,2,1)
for i in range(config.dimqxbranch):
    qzarray=Qzdomain[:,i]
    intrefarray=intref[:,i]
    uncertainarray=intuncertainty[:, i]
    intmodarray=intrandom[:,i]
    plt.errorbar(qzarray, intrefarray, yerr=uncertainarray, fmt='-', elinewidth=1.5, capsize=6, capthick=1.5,color=colorarray[i])
    plt.plot(qzarray, intmodarray,'--', markersize=5, label=f'mod. order={i}', color=colorarray[i])

plt.xlabel(r'$\mathrm{Q_z} \, (\mathrm{\AA}^{-1})$')
plt.ylabel('')
plt.yscale('log')
plt.title(rf'$I(Q_z)$: initial guess vs. ref.')
plt.legend()
#plt.grid()

plt.subplot(1,2,2)
for i in range(intref.shape[1]):
    qzarray=Qzdomain[:,i]
    intrefarray=intref[:,i]
    uncertainarray=intuncertainty[:, i]
    intmodarray=intrandom[:,i]
    plt.plot(qzarray, intrefarray,'-', color=colorarray[i])
    plt.plot(qzarray, intmodarray,'x', markersize=6, label=f'mod. order={i}', color=colorarray[i])

plt.xlabel(r'$\mathrm{Q_z} \, (\mathrm{\AA}^{-1})$')
plt.ylabel('')
plt.yscale('log')
plt.title(rf'$I(Q_z)$: initial guess vs. ref.')
plt.legend()
#plt.grid()

plt.show()

# %%
# Relative error report:
print("Relative error report:")
rltverrarray=[]
for i in range(config.dimqxbranch):
    array1=intref[:,i]
    array2=intrandom[:,i]
    rltverr=np.linalg.norm(array1-array2)/np.linalg.norm(array1)
    rltverrarray.append(rltverr)
    print(f"relative error of the {i+1}th peak, {rltverr:.2f}")
print(f"Overall relative error: {np.mean(rltverrarray):.2f}")

# %%
# Very good!!

# %%
# Part 3: Bayesian optimization.
#start server and connect client to it
server = Server()
client = Client(server.host)

# %%
# define search space.
design_space = [
 {'name': 'cd', 'domain': [28, 33]},
 {'name': 'h', 'domain': [27, 32]}
]
param_names = {param['name'] : '${' + '}_{\\rm '.join(param['name'].split('_')) + '}$' for param in design_space}

# define fixed parameter.
environment = [
{'name': 'pitch', 'type': 'fixed', 'domain': 80},
{'name': 'swa', 'type': 'fixed', 'domain': 71.56505117707799},
{'name': 'r_top', 'type': 'fixed', 'domain': 8.0},
{'name': 'r_bot', 'type': 'fixed', 'domain': 5.0}
]

# Before, constraints were met if they are smaller or equal zero. Now this is defined as unequality signs "<=" or ">="
# Key 'constraint' key was renamed to 'expression'
constraints = [
 {'name': 'r_top', 'expression': 'r_top + h/2/tan(PI*swa/180) <= cd/2 - 1'},
 {'name': 'r_bot', 'expression': 'r_bot + cd/2 + h/2/tan(PI*swa/180) <= pitch/2 - 1'},
 {'name': 'r_bot_t', 'expression': 'r_bot + cd/2 + h/2/tan(PI*swa/180) <= pitch/2 - 1'}
]

# %%
study = client.create_study(
    design_space=design_space,
    environment=environment,
    constraints=constraints,
    driver="BayesianLeastSquares",
    name="ParaRecon102",
    study_id="pararecon_attack_102", 
    save_dir=os.getcwd()
)

# %%
target_vector=[*[value for i in range(config.dimqxbranch) for value in intref[:, i]]]
uncertainty_vector=[*[value for i in range(config.dimqxbranch) for value in intuncertainty[:, i]]]

# %%
#study.set_parameters renamed to study.configure
study.configure(
    max_iter=10, target_vector=target_vector,
    uncertainty_vector=uncertainty_vector
)

# %%
#objective renamed to evaluator
def evaluate(study, **kwargs):
    observation = study.new_observation()
    intmod = fm.ModelEvaluate(kwargs,config=config)
    observation.add([
        *[value for i in range(config.dimqxbranch) for value in intmod[:, i]]     
    ])
    return observation
study.set_evaluator(evaluate)

# %%
study.run()

# %%
best_sample = study.driver.best_sample
min_chisq = study.driver.min_objective
uncertainties = study.driver.uncertainties
print(f"Reconstructed parameters with chi-squared value {min_chisq:.4e}:")
for param in design_space:
    name = param['name']
    print(f"  {name} = {best_sample[name]:.3f} +/- {uncertainties[name]:.3f}")

# %%
print(best_sample)

# %%
intopt=fm.ModelEvaluate(keys=best_sample,config=config)

# %%
# Optimized solution vs. reference.
colorarray=['blue','orange','black','green','red']
plt.figure(figsize=(12, 4))

plt.subplot(1,2,1)
for i in range(config.dimqxbranch):
    qzarray=Qzdomain[:,i]
    intrefarray=intref[:,i]
    uncertainarray=intuncertainty[:, i]
    intmodarray=intopt[:,i]
    plt.errorbar(qzarray, intrefarray, yerr=uncertainarray, fmt='-', elinewidth=1.5, capsize=6, capthick=1.5,color=colorarray[i])
    plt.plot(qzarray, intmodarray,'--', markersize=5, label=f'mod. order={i}', color=colorarray[i])

plt.xlabel(r'$\mathrm{Q_z} \, (\mathrm{\AA}^{-1})$')
plt.ylabel('')
plt.yscale('log')
plt.title(rf'$I(Q_z)$: opt. solution vs. ref.')
plt.legend()

plt.subplot(1,2,2)
for i in range(intref.shape[1]):
    qzarray=Qzdomain[:,i]
    intrefarray=intref[:,i]
    uncertainarray=intuncertainty[:, i]
    intmodarray=intopt[:,i]
    plt.plot(qzarray, intrefarray,'-', color=colorarray[i])
    plt.plot(qzarray, intmodarray,'x', markersize=6, label=f'mod. order={i}', color=colorarray[i])

plt.xlabel(r'$\mathrm{Q_z} \, (\mathrm{\AA}^{-1})$')
plt.ylabel('')
plt.yscale('log')
plt.title(rf'$I(Q_z)$: opt. solution vs. ref.')
plt.legend()

plt.show()

# %%
# Relative error report:
print("Relative error report:")
rltverrarray=[]
for i in range(config.dimqxbranch):
    array1=intref[:,i]
    array2=intopt[:,i]
    rltverr=np.linalg.norm(array1-array2)/np.linalg.norm(array1)
    rltverrarray.append(rltverr)
    print(f"relative error of the {i+1}th peak, {rltverr:.2f}")
print(f"Overall relative error: {np.mean(rltverrarray):.2f}")

# %%
# Part 4: extra check with the true solution.
truesol={'cd':30, 'h': 30}
intsol=fm.ModelEvaluate(keys=truesol,config=config)

# %%
# True solution vs. reference.
colorarray=['blue','orange','black','green','red']
plt.figure(figsize=(12, 4))

plt.subplot(1,2,1)
for i in range(config.dimqxbranch):
    qzarray=Qzdomain[:,i]
    intrefarray=intref[:,i]
    uncertainarray=intuncertainty[:, i]
    intmodarray=intsol[:,i]
    plt.errorbar(qzarray, intrefarray, yerr=uncertainarray, fmt='--', elinewidth=1.5, capsize=6, capthick=1.5,color=colorarray[i])
    plt.plot(qzarray, intmodarray,'-x', markersize=5, label=f'mod. order={i}', color=colorarray[i])

plt.xlabel(r'$\mathrm{Q_z} \, (\mathrm{\AA}^{-1})$')
plt.ylabel('')
plt.yscale('log')
plt.title(rf'$I(Q_z)$: opt. solution vs. ref.')
plt.legend()

plt.subplot(1,2,2)
for i in range(intref.shape[1]):
    qzarray=Qzdomain[:,i]
    intrefarray=intref[:,i]
    uncertainarray=intuncertainty[:, i]
    intmodarray=intsol[:,i]
    plt.plot(qzarray, intrefarray,'-', color=colorarray[i])
    plt.plot(qzarray, intmodarray,'x', markersize=6, label=f'mod. order={i}', color=colorarray[i])

plt.xlabel(r'$\mathrm{Q_z} \, (\mathrm{\AA}^{-1})$')
plt.ylabel('')
plt.yscale('log')
plt.title(rf'$I(Q_z)$: opt. solution vs. ref.')
plt.legend()

plt.show()

# %%
# Relative error report:
print("Relative error report:")
rltverrarray=[]
for i in range(config.dimqxbranch):
    array1=intref[:,i]
    array2=intsol[:,i]
    rltverr=np.linalg.norm(array1-array2)/np.linalg.norm(array1)
    rltverrarray.append(rltverr)
    print(f"relative error of the {i+1}th peak, {rltverr:.2f}")
print(f"Overall relative error: {np.mean(rltverrarray):.2f}")
